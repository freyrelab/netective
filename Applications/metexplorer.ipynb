# %%
import networkx as nx

# %%
import json
from networkx.readwrite import json_graph
def read_json_file(filename):
    with open(filename) as f:
        js_graph = json.load(f)
    return json_graph.node_link_graph(js_graph)


G = read_json_file(r"C:\Users\jmere\Downloads\MetExploreViz_10-30-2023.json")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\jmere\Dropbox (FreyreLab)\netective\Applications\metexplorer.ipynb Cell 2 line <cell line: 9>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>         js_graph = json.load(f)
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a>     return json_graph.node_link_graph(js_graph)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> G = read_json_file(r"C:\Users\jmere\Downloads\MetExploreViz_10-30-2023.json")
#
# c:\Users\jmere\Dropbox (FreyreLab)\netective\Applications\metexplorer.ipynb Cell 2 line read_json_file(filename)
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> with open(filename) as f:
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a>     js_graph = json.load(f)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> return json_graph.node_link_graph(js_graph)
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\json_graph\node_link.py:183, in node_link_graph(data, directed, multigraph, attrs)
#     181 graph.graph = data.get("graph", {})
#     182 c = count()
# --> 183 for d in data["nodes"]:
#     184     node = _to_tuple(d.get(name, next(c)))
#     185     nodedata = {str(k): v for k, v in d.items() if k != name}
#
# KeyError: 'nodes'

# %%
G = nx.read_gml(r"C:\Users\jmere\Downloads\MetExploreViz_10-30-2023.gml")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:186, in read_gml.<locals>.filter_lines(lines)
#     185 try:
# --> 186     line = line.decode("ascii")
#     187 except UnicodeDecodeError as err:
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xce in position 7: ordinal not in range(128)
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# c:\Users\jmere\Dropbox (FreyreLab)\netective\Applications\metexplorer.ipynb Cell 2 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/Applications/metexplorer.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> G = nx.read_gml(r"C:\Users\jmere\Downloads\MetExploreViz_10-30-2023.gml")
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\utils\decorators.py:845, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     844 def func(*args, __wrapper=None, **kwargs):
# --> 845     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:5, in argmap_read_gml_1(path, label, destringizer)
#       3 import gzip
#       4 import inspect
# ----> 5 import itertools
#       6 import re
#       7 from collections import defaultdict
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:195, in read_gml(path, label, destringizer)
#     192             line = line[:-1]
#     193         yield line
# --> 195 G = parse_gml_lines(filter_lines(path), label, destringizer)
#     196 return G
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:433, in parse_gml_lines(lines, label, destringizer)
#     430     return graph
#     432 tokens = tokenize()
# --> 433 graph = parse_graph()
#     435 directed = graph.pop("directed", False)
#     436 multigraph = graph.pop("multigraph", False)
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:422, in parse_gml_lines.<locals>.parse_graph()
#     421 def parse_graph():
# --> 422     curr_token, dct = parse_kv(next(tokens))
#     423     if curr_token.category is not None:  # EOF
#     424         unexpected(curr_token, "EOF")
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:368, in parse_gml_lines.<locals>.parse_kv(curr_token)
#     366     curr_token = next(tokens)
#     367 elif category == Pattern.DICT_START:
# --> 368     curr_token, value = parse_dict(curr_token)
#     369 else:
#     370     # Allow for string convertible id and label values
#     371     if key in ("id", "label", "source", "target"):
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:416, in parse_gml_lines.<locals>.parse_dict(curr_token)
#     414 curr_token = consume(curr_token, Pattern.DICT_START, "'['")
#     415 # dict contents
# --> 416 curr_token, dct = parse_kv(curr_token)
#     417 # dict end
#     418 curr_token = consume(curr_token, Pattern.DICT_END, "']'")
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:368, in parse_gml_lines.<locals>.parse_kv(curr_token)
#     366     curr_token = next(tokens)
#     367 elif category == Pattern.DICT_START:
# --> 368     curr_token, value = parse_dict(curr_token)
#     369 else:
#     370     # Allow for string convertible id and label values
#     371     if key in ("id", "label", "source", "target"):
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:416, in parse_gml_lines.<locals>.parse_dict(curr_token)
#     414 curr_token = consume(curr_token, Pattern.DICT_START, "'['")
#     415 # dict contents
# --> 416 curr_token, dct = parse_kv(curr_token)
#     417 # dict end
#     418 curr_token = consume(curr_token, Pattern.DICT_END, "']'")
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:358, in parse_gml_lines.<locals>.parse_kv(curr_token)
#     356 if category == Pattern.REALS or category == Pattern.INTS:
#     357     value = curr_token.value
# --> 358     curr_token = next(tokens)
#     359 elif category == Pattern.STRINGS:
#     360     value = unescape(curr_token.value[1:-1])
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:314, in parse_gml_lines.<locals>.tokenize()
#     312 tokens = re.compile("|".join(f"({pattern})" for pattern in patterns))
#     313 lineno = 0
# --> 314 for line in lines:
#     315     length = len(line)
#     316     pos = 0
#
# File c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\networkx\readwrite\gml.py:188, in read_gml.<locals>.filter_lines(lines)
#     186     line = line.decode("ascii")
#     187 except UnicodeDecodeError as err:
# --> 188     raise NetworkXError("input is not ASCII-encoded") from err
#     189 if not isinstance(line, str):
#     190     lines = str(lines)
#
# NetworkXError: input is not ASCII-encoded
