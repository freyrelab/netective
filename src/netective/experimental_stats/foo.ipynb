# %%
from pathlib import Path
foo = Path('.')

# %%
foo.exists()
# Out:
# True

# %%
import os

# %%
from netective import properties

# %%
pr.AverageClusteringCoefficient.CLASS_NAME
# Out:
# 'Average Clustering Coefficient'

# %%
from itertools import chain
import inspect

parent_class = properties._Property


def flatten_list_of_iterables(lst):
    return list(chain.from_iterable(lst))


def get_child_classes(parent_class:list):
    child_classes = []
    for name, obj in inspect.getmembers(properties):
        if (
            inspect.isclass(obj)
            and issubclass(obj, parent_class)
            and obj != parent_class
        ):
            child_classes.append(obj)
    return child_classes


child_classes = get_child_classes(parent_class)

# %%
child_classes(
# Out:
# {'Average Clustering Coefficient'}

# %%
all_classes
# Out:
# ['Average Clustering Coefficient',
#  'Average Degree for Nearest Neighbors (Undirected)',
#  'Average Local Efficiency',
#  'Average Degree for Nearest Neighbors (Out-Out)',
#  'Average Shortest Path Length',
#  'Betweenness Centrality',
#  'Center',
#  'Clustering Coefficient',
#  'Complex Feed-Forward Circuits',
#  'Density',
#  'Diameter',
#  'Eccentricity',
#  'Entropy of Degree Distribution',
#  '3-Feedback Loops',
#  'Gene % in the Giant Component',
#  'Gini Index',
#  'Global Efficiency',
#  'In-Degree',
#  'Locality Index',
#  'Max In-Dregree',
#  'Max Out-Degree',
#  'Out-Degree',
#  'Periphery',
#  'Radius',
#  'Regulators',
#  'Rich Club Coefficient',
#  'Self-Regulations',
#  'Subgraph Centrality']
