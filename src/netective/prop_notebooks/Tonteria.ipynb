# %%
from freyrelab.regnets.regnet import RegNet

from netective import pipeline as pip

# %%
G = RegNet()
n_nodes = 40
G.add_nodes_from(range(n_nodes))
G.add_edges_from([(i,j) for i in range(n_nodes//2) for j in range(n_nodes)])

# %%
pip.characterization(G, properties=['Radius', 'SubgraphCentrality'])
# Out:
# Properties used for analysis:  Radius SubgraphCentrality
#
# <class 'freyrelab.regnets.regnet.RegNet'>
# G:\Mi unidad\Respaldo\Genomicas\netective\src\netective\pipeline.py:250: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_dist.show()
# G:\Mi unidad\Respaldo\Genomicas\netective\src\netective\pipeline.py:253: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_scalar.show()
