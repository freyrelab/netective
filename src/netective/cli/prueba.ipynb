# %%
from netective import compare_structure
import os
path = './../../../data/test_comp/'
path2 = './../../../data/er_test/'
compare_structure(networks= path, verbose='warning', norm='network', erdos_renyi= 1);
# Out:
# [compare_structure] [WARNING] [Starting analysis of networks: ['lungs.genes', 'heart.genes', 'brain.genes']...]
#   0%|          | 0/3 [00:00<?, ?it/s]
# [run_parallel] [WARNING] [Finilized: brain.genes]
#  33%|███▎      | 1/3 [00:15<00:30, 15.22s/it]
# [run_parallel] [WARNING] [Finilized: heart.genes]
#  67%|██████▋   | 2/3 [00:19<00:08,  8.74s/it]
# [run_parallel] [WARNING] [Finilized: lungs.genes]
# 100%|██████████| 3/3 [00:25<00:00,  8.39s/it]
# [er_nets_per_net_analysis] [WARNING] [--------------------------------------------------------------------------------]
#
# [er_nets_per_net_analysis] [WARNING] [Starting analysis of 1 ER networks created from: lungs.genes...]
#
# [compare_structure] [WARNING] [Starting analysis of networks: ['ER_model_0_lungs.genes']...]
# 100%|██████████| 1/1 [00:14<00:00, 14.49s/it]
# [er_nets_per_net_analysis] [WARNING] [--------------------------------------------------------------------------------]
#
# ...

# %%
import networkx as nx
from netective import compare_structure
import os
foo = {
    'net_1' : nx.erdos_renyi_graph(100,0.2,directed=True),
    'net_2' : nx.erdos_renyi_graph(100,0.4,directed=True)
}

compare_structure(foo, verbose='warning', norm='network');
# Out:
# [compare_structure] [WARNING] [Starting analysis of networks: ['net_1', 'net_2']...]
#   0%|          | 0/2 [00:00<?, ?it/s]
# [run_parallel] [WARNING] [Finilized: net_1]
#  50%|█████     | 1/2 [00:03<00:03,  3.66s/it]
# [run_parallel] [WARNING] [Finilized: net_2]
# 100%|██████████| 2/2 [00:05<00:00,  2.60s/it]
