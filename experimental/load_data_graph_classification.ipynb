# %% [markdown]
#     In order to use the data for graph classification you have two options.
#
#         You either use Spektral (https://graphneural.network/getting-started/) or you use dgl (https://www.dgl.ai/pages/start.html)
#         I'm trying with specktal now.
#
#         Regarding the dataasets, I'm interested in the following:
#             * https://paperswithcode.com/dataset/proteins
#             * https://paperswithcode.com/dataset/reddit-binary

# %%
from spektral.datasets import TUDataset

# %%
dataset = TUDataset('PROTEINS')
dataset
# Out:
# Downloading PROTEINS dataset.
# 100%|█████████████████████████████████████████| 447k/447k [00:00<00:00, 572kB/s]
# c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# c:\Users\jmere\.conda\envs\pyfl38\lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Successfully loaded PROTEINS.
# TUDataset(n_graphs=1113)

# %%
foo = dataset[0]

# %%
foo.
# Out:
# (<42x42 sparse matrix of type '<class 'numpy.float64'>'
#  	with 162 stored elements in Compressed Sparse Row format>,)
