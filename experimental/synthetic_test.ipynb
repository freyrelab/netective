# %%
import networkx as nx

from freyrelab.regnets.regnet import RegNet
from netective.pipeline import compare_networks
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\jmere\Documents\GitHub\FreyreLab\netective\experimental\synthetic_test.ipynb Cell 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Documents/GitHub/FreyreLab/netective/experimental/synthetic_test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import networkx as nx
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Documents/GitHub/FreyreLab/netective/experimental/synthetic_test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from freyrelab.regnets.regnet import RegNet
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmere/Documents/GitHub/FreyreLab/netective/experimental/synthetic_test.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from netective.pipeline import compare_networks
#
# ModuleNotFoundError: No module named 'netective.pipeline'

# %%
networks = {}

for i in range (100, 501, 100):
    networks[f'ER_{i}'] = nx.erdos_renyi_graph(i, 0.1)
    networks[f'BA_{i}'] = nx.barabasi_albert_graph(i, 10)
    networks[f'WS_{i}'] = nx.watts_strogatz_graph(i, 10, 0.1)
    networks[f'CG_{i}'] = nx.complete_graph(i)
    networks[f'SF_{i}'] = nx.scale_free_graph(i)

# %%
compare_networks(networks)
# Out:
# 25it [21:21, 51.26s/it]
# (<Figure size 1000x1000 with 4 Axes>, <Figure size 1000x1000 with 4 Axes>)

# %%
compare_networks(networks, norm='network')
# Out:
# 25it [21:18, 51.15s/it]
# (<Figure size 1000x1000 with 4 Axes>, <Figure size 1000x1000 with 4 Axes>)

# %%
compare_networks(networks, norm='biological')
