# %% [markdown]
# ## Sampling Generator Fxn
# #### Recibe
# - Red como objeto RegNet
# - Step (step para el porcentaje sampleo)
# - Repeticiones por step
# - Tipo de sampleo (nodos, edges, snowball)
# #### Regresa
# - Diccionario con llaves como el identificador y value el sampleo asociado
#
# link_sampling - freyrelab.network.sampling
#
#
# node_sampling - freyrelab.network.sampling

# %% [markdown]
# #### Imports

# %%
from freyrelab.abasy import Abasy
a = Abasy()
list(a.select_regnets(strong=True))
# Out:
# ['208964_v2020_sRPA20_eStrong',
#  '511145_v2022_sRDB22_eStrong',
#  '100226_v2019_sA22-DBSCR15_eStrong',
#  '196627_v2020_s21_eStrong',
#  '224308_v2008_sDBTBS08_eStrong']

# %%
a.regnet('208964_v2020_sRPA20_eStrong')

# %%
from __future__ import annotations
from freyrelab.nets.sampling import edge_sampling, node_sampling, snowball_sampling
from freyrelab.regnets.regnet import RegNet
import networkx as nx
from netective.utils import *
import random

# %%
random.seed(42)
G = nx.fast_gnp_random_graph(100, 0.1, seed=42)
edge_sampling(G, 10).edges()
# Out:
# EdgeView([(42, 91), (42, 6), (1, 59), (54, 65), (54, 55), (14, 22), (12, 56), (11, 75), (7, 74), (5, 61)])

# %%
len(edge_sampling(G, 100).edges()), len(G.edges())
# Out:
# (100, 478)

# %% [markdown]
# #### Fxn

# %%
def get_samples(G: RegNet | nx.DiGraph,  
                step: int=10, 
                rep: int=10,
                sampling_type : str='node',
                deterministic: bool=False 
):
    """
        Function to create sampling networks.

        Args:
            G: RegNet or DiGraph.
                Network to compute the structural properties.
            step: int.
                Base level of network coverage for sampling and step for each
                increase until reaching 100% of coverage.
                Default is 10.
            rep: int.
                Number of samples per step.
                Default is 10.
            sampling_type: str.
                Network attribute by which sampling is done.
                Sampling types admitted: node-based, edge-based and snowball effect.
                Default is node-based sampling.

        Returns:
            nets : dictionary where keys as IDs for each network and its value is the sampled network.

        Raises:
            TypeError: If G is not a RegNet or DiGraph.
            ValueError: If user introduces a sampling type not admitted.
        """
    
    G = validate_network(G)
    # Validation for admitted sampling options
    sampling_opt = ['node', 'edge', 'snowball']
    if sampling_type not in sampling_opt:
        raise ValueError(f'Invalid sampling type, sampling options: {sampling_opt}')
    
    sampling_fxns = {
        'node' : node_sampling,
        'edge' : edge_sampling,
        'snowball' : snowball_sampling
    }
    

    nets = {}
    for x,i in enumerate(range(step, 101, step), 1):
        for j in range(rep):
            if deterministic:
                random.seed(j)
            nets[f'Net_{sampling_type}_{step * x}_{j}'] = sampling_fxns[sampling_type](G, size=i)
    
    return nets

# %%
import pickle
with open('../208964_v2020_sRPA20_eStrong.pkl', 'rb') as f:
    data = pickle.load(f)
data['scalar_networknorm_208964_v2020_sRPA20_eStrong']
# Out:
# {'208964_v2020_sRPA20_eStrong_node_50_0': {'Average Local Efficiency': 0.0928910417936567,
#   'Average Shortest Path Length': 0.013900625777049811,
#   'Center': 0.0033112582781456954,
#   'Diameter': 0.046511627906976744,
#   'Global Efficiency': 0.2808569876142647,
#   'Periphery': 0.009933774834437087,
#   'Radius': 0.023255813953488372,
#   'Entropy of Degree Distribution': 0.2521625753403189,
#   'Max Degree': 0.12237093690248566,
#   'Self-Loops': 0.04397705544933078,
#   'Undirected Gini Index': 0.643079948096448,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.004769527652295952,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.034647100922427836,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.001549975500417665,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': 0.9658769911905256,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.3171926657152193,
#   'Average Clustering Coefficient': 0.050226768129762754,
#   'Variation Clustering Coefficient': 0.0384862504391528,
#   'Skewness Clustering Coefficient': 4.228601198331711,
#   'Kurtosis Clustering Coefficient': 16.888191852047843,
#   'Average Betweenness Centrality': 0.01061362786297331,
#   'Variation Betweenness Centrality': 0.001340048105175826,
#   'Skewness Betweenness Centrality': 5.959887850385017,
#   'Kurtosis Betweenness Centrality': 40.828608030751475,
#   'Average Eccentricity': 0.03235352357483884,
#   'Variation Eccentricity': 1.2993132756636561e-05,
#   'Skewness Eccentricity': 0.7985099207078733,
#   'Kurtosis Eccentricity': 2.101262927714113,
#   'Average Degree': 0.0038679628119870284,
#   'Variation Degree': 9.799352258888271e-05,
#   'Skewness Degree': 7.7469417320106135,
#   'Kurtosis Degree': 71.60373952614921,
#   'Average Locality Index': 0.07183260876147429,
#   'Variation Locality Index': 0.029613238375559462,
#   'Skewness Locality Index': 4.042779020058898,
#   'Kurtosis Locality Index': 17.51849844993863,
#   'Average Subgraph Centrality': 3.89493253585904e-223,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan},
#  '208964_v2020_sRPA20_eStrong_node_100_0': {'Average Local Efficiency': 0.09695399905826414,
#   'Average Shortest Path Length': 0.004134540554931123,
#   'Center': 0.001053740779768177,
#   'Diameter': 0.010548523206751054,
#   'Global Efficiency': 0.2816765304453876,
#   'Periphery': 0.030558482613277135,
#   'Radius': 0.005274261603375527,
#   'Entropy of Degree Distribution': 0.24937103875962247,
#   'Max Degree': 0.12607449856733524,
#   'Self-Loops': 0.03629417382999045,
#   'Undirected Gini Index': 0.6044392157994896,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.0021130334076910865,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.04599911254774426,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.0012696878598280144,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': 0.48510307547725423,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.8503853817275608,
#   'Average Clustering Coefficient': 0.08126434594086812,
#   'Variation Clustering Coefficient': 0.05713011929673552,
#   'Skewness Clustering Coefficient': 3.2062101725560144,
#   'Kurtosis Clustering Coefficient': 9.074794602851478,
#   'Average Betweenness Centrality': 0.0030829402809658952,
#   'Variation Betweenness Centrality': 0.00020456074958385598,
#   'Skewness Betweenness Centrality': 8.217585097144706,
#   'Kurtosis Betweenness Centrality': 78.15443315400431,
#   'Average Eccentricity': 0.007687416912317206,
#   'Variation Eccentricity': 7.963480461849325e-07,
#   'Skewness Eccentricity': 1.0160670978550057,
#   'Kurtosis Eccentricity': 1.7394957241457156,
#   'Average Degree': 0.00362157216370236,
#   'Variation Degree': 9.408630093917295e-05,
#   'Skewness Degree': 8.096282123826507,
#   'Kurtosis Degree': 78.24625832211204,
#   'Average Locality Index': 0.03763890318368012,
#   'Variation Locality Index': 0.014010495129994109,
#   'Skewness Locality Index': 6.125081737414932,
#   'Kurtosis Locality Index': 42.11867493144152,
#   'Average Subgraph Centrality': 0.0,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan},
#  '208964_v2020_sRPA20_eStrong_edge_50_0': {'Average Local Efficiency': 0.03272000477840561,
#   'Average Shortest Path Length': 0.007312357146203677,
#   'Center': 0.0031545741324921135,
#   'Diameter': 0.018957345971563982,
#   'Global Efficiency': 0.24406763316790686,
#   'Periphery': 0.015772870662460567,
#   'Radius': 0.009478672985781991,
#   'Entropy of Degree Distribution': 0.2151811036863747,
#   'Max Degree': 0.09217877094972067,
#   'Self-Loops': 0.030726256983240222,
#   'Undirected Gini Index': 0.5459616518345916,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.0023211495785608375,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.033611745510520825,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.0007593951508185475,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': 0.6087456879405314,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.7672436644909486,
#   'Average Clustering Coefficient': 0.0279217596551531,
#   'Variation Clustering Coefficient': 0.021559985220320693,
#   'Skewness Clustering Coefficient': 6.009190727776225,
#   'Kurtosis Clustering Coefficient': 35.863917573139965,
#   'Average Betweenness Centrality': 0.005741648850548938,
#   'Variation Betweenness Centrality': 0.00041106641472326015,
#   'Skewness Betweenness Centrality': 6.954484995387663,
#   'Kurtosis Betweenness Centrality': 58.59446690534673,
#   'Average Eccentricity': 0.013587593005118082,
#   'Variation Eccentricity': 2.6969320707508486e-06,
#   'Skewness Eccentricity': 0.8362788905310407,
#   'Kurtosis Eccentricity': 0.5551609540825124,
#   'Average Degree': 0.003881745263880653,
#   'Variation Degree': 6.997463171152295e-05,
#   'Skewness Degree': 6.614686862952365,
#   'Kurtosis Degree': 51.539605946013126,
#   'Average Locality Index': 0.036292177773147284,
#   'Variation Locality Index': 0.017638781839627617,
#   'Skewness Locality Index': 5.86170489351766,
#   'Kurtosis Locality Index': 36.70085973534309,
#   'Average Subgraph Centrality': 0.0,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan},
#  '208964_v2020_sRPA20_eStrong_edge_100_0': {'Average Local Efficiency': 0.09695399905826413,
#   'Average Shortest Path Length': 0.004134540554931123,
#   'Center': 0.001053740779768177,
#   'Diameter': 0.010548523206751054,
#   'Global Efficiency': 0.2816765304453877,
#   'Periphery': 0.030558482613277135,
#   'Radius': 0.005274261603375527,
#   'Entropy of Degree Distribution': 0.24937103875962247,
#   'Max Degree': 0.12607449856733524,
#   'Self-Loops': 0.03629417382999045,
#   'Undirected Gini Index': 0.6044392157994896,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.0021130334076910865,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.04599911254774426,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.0012696878598280144,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': 0.48510307547725423,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.8503853817275608,
#   'Average Clustering Coefficient': 0.08126434594086811,
#   'Variation Clustering Coefficient': 0.05713011929673554,
#   'Skewness Clustering Coefficient': 3.206210172556014,
#   'Kurtosis Clustering Coefficient': 9.074794602851474,
#   'Average Betweenness Centrality': 0.003082940280965895,
#   'Variation Betweenness Centrality': 0.00020456074958385569,
#   'Skewness Betweenness Centrality': 8.217585097144699,
#   'Kurtosis Betweenness Centrality': 78.15443315400417,
#   'Average Eccentricity': 0.007687416912317206,
#   'Variation Eccentricity': 7.963480461849325e-07,
#   'Skewness Eccentricity': 1.0160670978550057,
#   'Kurtosis Eccentricity': 1.7394957241457139,
#   'Average Degree': 0.0036215721637023594,
#   'Variation Degree': 9.408630093917293e-05,
#   'Skewness Degree': 8.096282123826507,
#   'Kurtosis Degree': 78.24625832211207,
#   'Average Locality Index': 0.03763890318368012,
#   'Variation Locality Index': 0.014010495129994109,
#   'Skewness Locality Index': 6.125081737414933,
#   'Kurtosis Locality Index': 42.11867493144152,
#   'Average Subgraph Centrality': 0.0,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan},
#  '208964_v2020_sRPA20_eStrong_snowball_50_0': {'Average Local Efficiency': 0.13757130145719887,
#   'Average Shortest Path Length': 0.006315362873245914,
#   'Center': 0.16988416988416988,
#   'Diameter': 0.01160541586073501,
#   'Global Efficiency': 0.3336545857822453,
#   'Periphery': 0.1583011583011583,
#   'Radius': 0.007736943907156673,
#   'Entropy of Degree Distribution': 0.2610653689650315,
#   'Max Degree': 0.22753346080305928,
#   'Self-Loops': 0.02676864244741874,
#   'Undirected Gini Index': 0.6167889964843027,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.003697023002042307,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.11828509123568194,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.003762095261845197,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': -0.1583769179629753,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.8363274669648,
#   'Average Clustering Coefficient': 0.12697969445570056,
#   'Variation Clustering Coefficient': 0.08980834531292159,
#   'Skewness Clustering Coefficient': 2.307855632230988,
#   'Kurtosis Clustering Coefficient': 3.7562907225311513,
#   'Average Betweenness Centrality': 0.0043896174524576306,
#   'Variation Betweenness Centrality': 0.0005520444284349061,
#   'Skewness Betweenness Centrality': 8.734466063666009,
#   'Kurtosis Betweenness Centrality': 91.78157760773281,
#   'Average Eccentricity': 0.009648775606222414,
#   'Variation Eccentricity': 1.2297015230249584e-06,
#   'Skewness Eccentricity': -0.0009686127973417414,
#   'Kurtosis Eccentricity': 0.04701930415497557,
#   'Average Degree': 0.007253344252346186,
#   'Variation Degree': 0.00043748958218253834,
#   'Skewness Degree': 7.068665899240352,
#   'Kurtosis Degree': 54.31897089038366,
#   'Average Locality Index': 0.02082994278053644,
#   'Variation Locality Index': 0.0019706929133663145,
#   'Skewness Locality Index': 5.227041333381864,
#   'Kurtosis Locality Index': 31.62865894303301,
#   'Average Subgraph Centrality': 9.947350568315345e-221,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan},
#  '208964_v2020_sRPA20_eStrong_snowball_100_0': {'Average Local Efficiency': 0.09695399905826414,
#   'Average Shortest Path Length': 0.004134540554931123,
#   'Center': 0.001053740779768177,
#   'Diameter': 0.010548523206751054,
#   'Global Efficiency': 0.2816765304453876,
#   'Periphery': 0.030558482613277135,
#   'Radius': 0.005274261603375527,
#   'Entropy of Degree Distribution': 0.24937103875962247,
#   'Max Degree': 0.12607449856733524,
#   'Self-Loops': 0.03629417382999045,
#   'Undirected Gini Index': 0.6044392157994896,
#   'Gene % in the Giant Component': 1.0,
#   'Undirected Density': 0.0021130334076910865,
#   'Average Average Degree for Nearest Neighbors (Undirected)': 0.04599911254774426,
#   'Variation Average Degree for Nearest Neighbors (Undirected)': 0.0012696878598280144,
#   'Skewness Average Degree for Nearest Neighbors (Undirected)': 0.48510307547725423,
#   'Kurtosis Average Degree for Nearest Neighbors (Undirected)': -0.8503853817275608,
#   'Average Clustering Coefficient': 0.08126434594086812,
#   'Variation Clustering Coefficient': 0.05713011929673552,
#   'Skewness Clustering Coefficient': 3.2062101725560144,
#   'Kurtosis Clustering Coefficient': 9.074794602851478,
#   'Average Betweenness Centrality': 0.0030829402809658952,
#   'Variation Betweenness Centrality': 0.00020456074958385598,
#   'Skewness Betweenness Centrality': 8.217585097144706,
#   'Kurtosis Betweenness Centrality': 78.15443315400431,
#   'Average Eccentricity': 0.007687416912317206,
#   'Variation Eccentricity': 7.963480461849325e-07,
#   'Skewness Eccentricity': 1.0160670978550057,
#   'Kurtosis Eccentricity': 1.7394957241457156,
#   'Average Degree': 0.00362157216370236,
#   'Variation Degree': 9.408630093917295e-05,
#   'Skewness Degree': 8.096282123826507,
#   'Kurtosis Degree': 78.24625832211204,
#   'Average Locality Index': 0.03763890318368012,
#   'Variation Locality Index': 0.014010495129994109,
#   'Skewness Locality Index': 6.125081737414932,
#   'Kurtosis Locality Index': 42.11867493144152,
#   'Average Subgraph Centrality': 0.0,
#   'Variation Subgraph Centrality': 0.0,
#   'Skewness Subgraph Centrality': nan,
#   'Kurtosis Subgraph Centrality': nan}}

# %% [markdown]
# ####

# %%
ER = nx.erdos_renyi_graph(n=574, p=0.07, directed=True)
ER_RegNet = RegNet(ER)
