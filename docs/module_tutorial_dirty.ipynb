# %% [markdown]
# <img src=".\assets\on_black.png" alt="netective logo" style="width:18%;">
#
# Compare networks based on their structure and performance statistics.
# <br><br>
# ## Python Module Tutorial
#
# Explore the main features of the Python module for network comparison.
#
# - For a tutorial on the command-line interface, refer to [this link]().
# - Access the web service for small jobs [here]().
#
# ---
#
# The module consists of two submodules: `structure` and `stats`, each with module-level functions for convenient usage.
#
# In this guide, we'll cover the following topics:
#
# 1. **Module-level functions** 📦
# 2. **Submodule `structure`** 🕸️📐
#    Useful for comparing networks with different node IDs.
#
# 3. **Submodule `stats`** 📊
#    Requires networks to share node IDs. Useful for comparing inferred networks against a gold standard.

# %% [markdown]
# <br>

# %% [markdown]
# Make sure to have netective installed:

# %%
# %pip install netective

# %% [markdown]
# <br>

# %% [markdown]
# ### Module-level functions 📦
#
# The module-level functions empower users, even those with basic Python proficiency, to seamlessly employ netective to characterize network structure, compare networks, and assess inference performance.

# %%
# Third-party imports
import networkx as nx
from scipy.stats import spearmanr

# %% [markdown]
# #### characterize network structure

# %% [markdown]
# #### characterize network structure

# %%
NumberNodesFake.__name__
# Out:
# 'NumberNodesFake'

# %%
import inspect
parent_class = _Property
user_globals = globals().copy()
for name, obj in user_globals.items():
    if inspect.isclass(obj) and issubclass(obj, parent_class) and obj != parent_class:
        print(f'{name} is a user defined property')
# Out:
# NumberNodesFake is a user defined property

# %%
from netective.structure import properties
inspect.getmembers(properties)[3]
# Out:
# ('AverageOutDegreeNearestNeighbors',
#  netective.structure.properties.AverageOutDegreeNearestNeighbors)

# %%
from netective import characterize_network

# Let's create a random network to characterize
G = nx.erdos_renyi_graph(100, 0.3, directed=True)

# Characterize the network is as simple as calling the function with the network and an identifier as arguments
characterize_network(G, "my_network", user_globals=globals(), verbose='DEBUG')
# Out:
# [get_props] [WARNING] [The network or the normalization method has changed. Computing its properties...]
# [INFO] Processing my_network...
# [INFO] my_network has 100 nodes and 3020 edges.
# [10/18/2023 03:11:12 PM] [structure] [_compute_props] [572] [Starting properties computation...]
# [10/18/2023 03:11:12 PM] [structure] [_compute_props] [578] [Finished computing: Average Degree for Nearest Neighbors (Undirected)]
# [10/18/2023 03:11:12 PM] [structure] [_compute_props] [578] [Finished computing: Clustering Coefficient]
# [10/18/2023 03:11:12 PM] [structure] [_compute_props] [578] [Finished computing: Rich Club Coefficient]
# [10/18/2023 03:11:12 PM] [structure] [_compute_props] [578] [Finished computing: Number of nodes Fake]
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', '# %pip install netective', '# Third-party imports\nimport networkx as nx\nfrom scipy.stats import spearmanr', 'from netective.structure.properties import _Property, return_scalar\n\n@return_scalar\nclass NumberNodesFake(_Property):\n    CLASS_NAME = "Number of nodes Fake"\n\n    def __init__(self, G: nx.DiGraph):\n        """\n        Args:\n            G (nx.DiGraph): Directed graph.\n        """\n        super().__init__(G)\n    \n    def compute(self):\n        self._raw_value = 1\n        return self._raw_value\n    \n    def norm_biol(self):\n        return self._raw_value\n    \n    def norm_network(self):\n        return self._raw_value', 'NumberNodesFake.__name__', "import inspect\nparent_class = _Property\nuser_globals = globals().copy()\nfor name, obj in user_globals.items():\n    if inspect.isclass(obj) and issubclass(obj, parent_class) and obj != parent_class:\n        print(f'{name} is a user defined property')", 'from netective.structure import properties\ninspect.getmembers(properties)[3]', 'from netective import characterize_network\n\n# Let\'s create a random network to characterize\nG = nx.erdos_renyi_graph(100, 0.3, directed=True)\n\n# Characterize the network is as simple as calling the function with the network and an identifier as arguments\ncharacterize_network(G, "my_network", user_globals=globals(), verbose=\'DEBUG\')'], '_oh': {4: 'NumberNodesFake', 6: ('AverageOutDegreeNearestNeighbors', <class 'netective.structure.properties.AverageOutDegreeNearestNeighbors'>)}, '_dh': [WindowsPath('c:/Users/jmere/Dropbox (FreyreLab)/netective/docs')], 'In': ['', '# %pip install netective', '# Third-party imports\nimport networkx as nx\nfrom scipy.stats import spearmanr', 'from netective.structure.properties import _Property, return_scalar\n\n@return_scalar\nclass NumberNodesFake(_Property):\n    CLASS_NAME = "Number of nodes Fake"\n\n    def __init__(self, G: nx.DiGraph):\n        """\n        Args:\n            G (nx.DiGraph): Directed graph.\n        """\n        super().__init__(G)\n    \n    def compute(self):\n        self._raw_value = 1\n        return self._raw_value\n    \n    def norm_biol(self):\n        return self._raw_value\n    \n    def norm_network(self):\n        return self._raw_value', 'NumberNodesFake.__name__', "import inspect\nparent_class = _Property\nuser_globals = globals().copy()\nfor name, obj in user_globals.items():\n    if inspect.isclass(obj) and issubclass(obj, parent_class) and obj != parent_class:\n        print(f'{name} is a user defined property')", 'from netective.structure import properties\ninspect.getmembers(properties)[3]', 'from netective import characterize_network\n\n# Let\'s create a random network to characterize\nG = nx.erdos_renyi_graph(100, 0.3, directed=True)\n\n# Characterize the network is as simple as calling the function with the network and an identifier as arguments\ncharacterize_network(G, "my_network", user_globals=globals(), verbose=\'DEBUG\')'], 'Out': {4: 'NumberNodesFake', 6: ('AverageOutDegreeNearestNeighbors', <class 'netective.structure.properties.AverageOutDegreeNearestNeighbors'>)}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002B32FA12040>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000002B32FA12880>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000002B32FA12880>, '_': ('AverageOutDegreeNearestNeighbors', <class 'netective.structure.properties.AverageOutDegreeNearestNeighbors'>), '__': 'NumberNodesFake', '___': '', '__vsc_ipynb_file__': 'c:\\Users\\jmere\\Dropbox (FreyreLab)\\netective\\docs\\module_tutorial.ipynb', '_i': 'from netective.structure import properties\ninspect.getmemb ...
# NumberNodesFake is a used defined property
# {<class 'netective.structure.properties.AverageDegreeNearestNeighbors'>: 0, <class 'netective.structure.properties.AverageLocalEfficiency'>: 3, <class 'netective.structure.properties.AverageOutDegreeNearestNeighbors'>: 8, <class 'netective.structure.properties.AverageShortestPathLength'>: 3, <class 'netective.structure.properties.BetweennessCentrality'>: 3, <class 'netective.structure.properties.Center'>: 3, <class 'netective.structure.properties.ClusteringCoefficient'>: 0, <class 'netective.structure.properties.ComplexFeedForwardCircuits'>: 24, <class 'netective.structure.properties.Degree'>: 4, <class 'netective.structure.properties.Density'>: 14, <class 'netective.structure.properties.Diameter'>: 3, <class 'netective.structure.properties.Eccentricity'>: 3, <class 'netective.structure.properties.EntropyPK'>: 4, <class 'netective.structure.properties.EntropyPKout'>: 12, <class 'netective.structure.properties.FeedForwardCircuits'>: 24, <class 'netective.structure.properties.FeedbackLoops_3'>: 24, <class 'netective.structure.properties.GenesintheGiantComponent'>: 2, <class 'netective.structure.properties.GiniIndex'>: 12, <class 'netective.structure.properties.GlobalEfficiency'>: 3, <class 'netective.structure.properties.InDegree'>: 12, <class 'netective.structure.properties.LocalityIndex'>: 4, <class 'netective.structure.properties.MaxDegree'>: 4, <class 'netective.structure.properties.MaxInDegree'>: 12, <class 'netective.structure.properties.MaxOutDegree'>: 12, <class 'netective.structure.properties.NumberArcs'>: 12, <class 'netective.structure.properties.NumberEdges'>: 4, <class 'netective.structure.properties.NumberNodes'>: 4, <class 'netective.structure.properties.OutDegree'>: 12, <class 'netective.structure.properties.Periphery'>: 3, <class 'netective.structure.properties.Radius'>: 3, <class 'netective.structure.properties.Regulators'>: 12, <class 'netective.structure.properties.RichClub'>: 0, <class 'netective.structure.properties.SelfLoops'>: 4, <class 'netective.structure.properties.SelfRegulations'>: 12, <class 'netective.structure.properties.SubgraphCentrality'>: 4, <class 'netective.structure.properties.UndirDensity'>: 6, <class 'netective.structure.properties.UndirGiniIndex'>: 4, <class '__main__.NumberNodesFake'>: 0}
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Average Local Efficiency]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Average Shortest Path Length]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Betweenness Centrality]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Center]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Diameter]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Eccentricity]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Global Efficiency]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Periphery]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Radius]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Average Degree for Nearest Neighbors (Out-Out)]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Complex Feed-Forward Circuits]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Feed-Forward Circuits]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: 3-Feedback Loops]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Degree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Entropy of Degree Distribution]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Locality Index]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Max Degree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Number of Edges]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Number of Nodes]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Self-Loops]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Subgraph Centrality]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Undirected Gini Index]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Density]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Entropy of Out-Degree Distribution]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Gini Index]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: In-Degree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Max In-Dregree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Max Out-Degree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Number of Arcs]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Out-Degree]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Regulators]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Self Regulations]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Gene % in the Giant Component]
# [10/18/2023 03:11:13 PM] [structure] [_compute_props] [578] [Finished computing: Undirected Density]
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:273: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = skew(data, nan_policy="omit")
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:274: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt = kurtosis(data, nan_policy="omit")
# (<Figure size 200x810 with 1 Axes>, <Figure size 1200x750 with 11 Axes>)

# %% [markdown]
# Networks may have different size. Use the norm parameter to get normalized values.

# %%
# norm parameter allows you to normalize data using different approaches depending on the nature of the networks analyzed
# default is None for no normalization, uses raw data
# norm = "network" normalize the network by the network size

characterize_network(G, "my_network", norm="network", verbose='info')
# Out:
# [get_props] [WARNING] [The network or the normalization method has changed. Computing its properties...]
# [INFO] Processing my_network...
# [INFO] my_network has 100 nodes and 3026 edges.
# [INFO] Normalizing...
# [_normalize_props] [WARNING] [Properties excluded from analysis due to lack of normalization:]
# [_normalize_props] [WARNING] [Rich Club Coefficient]
# [_normalize_props] [WARNING] [Number of Edges]
# [_normalize_props] [WARNING] [Number of Nodes]
# [_normalize_props] [WARNING] [Number of Arcs]
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:273: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = skew(data, nan_policy="omit")
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:274: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt = kurtosis(data, nan_policy="omit")
# (<Figure size 200x690 with 1 Axes>, <Figure size 1200x750 with 10 Axes>)

# %%
# norm = "biological" normalize the network by the number of regulators

characterize_network(G, "my_network", norm="biological")
# Out:
# [get_props] [WARNING] [The network or the normalization method has changed. Computing its properties...]
# [_normalize_props] [WARNING] [Properties excluded from analysis due to lack of normalization:]
# [_normalize_props] [WARNING] [Average Degree for Nearest Neighbors (Undirected)]
# [_normalize_props] [WARNING] [Clustering Coefficient]
# [_normalize_props] [WARNING] [Rich Club Coefficient]
# [_normalize_props] [WARNING] [Average Local Efficiency]
# [_normalize_props] [WARNING] [Average Shortest Path Length]
# [_normalize_props] [WARNING] [Betweenness Centrality]
# [_normalize_props] [WARNING] [Center]
# [_normalize_props] [WARNING] [Diameter]
# [_normalize_props] [WARNING] [Eccentricity]
# [_normalize_props] [WARNING] [Global Efficiency]
# [_normalize_props] [WARNING] [Periphery]
# [_normalize_props] [WARNING] [Radius]
# [_normalize_props] [WARNING] [Degree]
# [_normalize_props] [WARNING] [Entropy of Degree Distribution]
# [_normalize_props] [WARNING] [Locality Index]
# [_normalize_props] [WARNING] [Max Degree]
# [_normalize_props] [WARNING] [Number of Edges]
# [_normalize_props] [WARNING] [Number of Nodes]
# [_normalize_props] [WARNING] [Self-Loops]
# [_normalize_props] [WARNING] [Subgraph Centrality]
# [_normalize_props] [WARNING] [Undirected Gini Index]
# [_normalize_props] [WARNING] [Number of Arcs]
# [_normalize_props] [WARNING] [Gene % in the Giant Component]
# [_normalize_props] [WARNING] [Undirected Density]
# (<Figure size 200x300 with 1 Axes>, <Figure size 600x450 with 3 Axes>)

# %% [markdown]
# Netective v1.0 uses a total of 28 network properties for characterization and comparison:
#
# `Node-Level Properties`
# - In-Degree (InDegre)
# - Out-Degree (OutDegre)
# - Locality Index (LocalityIndex)
# - Subgraph Centrality (SubgraphCentrality)
# - Average Degree of Nearest Neighbors using out-out degree (AverageOutDegreeNearestNeighbors)
# - Average Degree of Nearest Neighbors using undirected network (AverageDegreeNearestNeighbors)
# - Clustering Coefficient (ClusteringCoefficient)
# - Rich Club Coefficient (RichClub)
# - Betweenness Centrality (BetweennessCentrality)
# - Eccentricity (Eccentricity)
#
# `Network-Level Properties`
# - Entropy of Degree Distribution (EntropyPKout)
# - Gini Index (GiniIndex)
# - Max In-Degree (MaxInDegree)
# - Max Out-Degree (MaxOutDegree)
# - Regulators (Regulators)
# - Self-Regulations (SelfRegulations)
# - Density (Density)
# - Complex Feed-Forward Circuits (ComplexFeedForwardCircuits)
# - 3-Feedback Loops (FeedbakcLoops_3)
# - Average Clustering Coefficient (AverageClusteringCoefficient)
# - Gene % in the Giant Component (GenesintheGiantComponent)
# - Average Local Efficiency (AverageLocalEfficiency)
# - Average Shortest Path Length (AverageShortestPathLength)
# - Center (Center)
# - Diameter (Diameter)
# - Global Efficiency (GlobalEfficiency)
# - Periphery (Periphery)
# - Radius (Radius)
#
# ***correct spelling for list in parenthesis***
#
# characterize_network function allows you to provide a list of chosen properties to use if you do not want to use the complete set, using the parameter selected_props ***default is all properties***

# %%
# using the same network

my_properties = ['Gini Index', 'Density', 'Diameter', 'LocalityIndex', 'InDegree', 'RichClub', '3-Feedback Loops']

characterize_network(G, "my_network", norm="network", selected_props= my_properties)
# Out:
# [get_props] [WARNING] [The network or the normalization method has changed. Computing its properties...]
# [_normalize_props] [WARNING] [Properties excluded from analysis due to lack of normalization:]
# (<Figure size 200x120 with 1 Axes>, None)

# %% [markdown]
# #### compare networks based on their structure

# %%
from netective import compare_structure
import networkx as nx

# Let's create a random network to characterize
G = nx.erdos_renyi_graph(100, 0.3, directed=True)
# Let's create a second network to compare to the first one.
H = nx.path_graph(50, create_using=nx.DiGraph)

# Comparing both networks is as simple as calling the function with a dictionary of networks.
networks = {"my_network_G": G, "my_network_H": H}
compare_structure(networks, return_prop_dicts=False, erdos_renyi=30, verbose='info', norm="network");
# Out:
# [INFO] Starting analysis of inputed networks...
#   0%|          | 0/2 [00:00<?, ?it/s]
# [INFO] Running my_network_G...
# [INFO] Running my_network_H...
# [INFO] Finilized: my_network_H
#  50%|█████     | 1/2 [00:01<00:01,  1.57s/it]
# [INFO] Finilized: my_network_G
# 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# 100%|██████████| 30/30 [00:07<00:00,  3.81it/s]
# 100%|██████████| 30/30 [00:04<00:00,  7.24it/s]

# %%
from netective import compare_structure
import networkx as nx

# Let's create a random network to characterize
G = nx.erdos_renyi_graph(100, 0.3, directed=True)
F = nx.erdos_renyi_graph(50, 50/50**2, directed=True)
# Let's create a second network to compare to the first one.
H = nx.path_graph(50, create_using=nx.DiGraph)

# Comparing both networks is as simple as calling the function with a dictionary of networks.
networks = {"my_network_G": G, "my_network_H": H, "my_network_F": F}
compare_structure(networks, return_prop_dicts=False, verbose='info', norm="network");
# Out:
# [INFO] Starting analysis of inputed networks...
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] Running my_network_G...
# [INFO] Running my_network_H...
# [INFO] Running my_network_F...
# [INFO] Finilized: my_network_H
#  33%|███▎      | 1/3 [00:01<00:03,  1.59s/it]
# [INFO] Finilized: my_network_F
# [INFO] Finilized: my_network_G
# 100%|██████████| 3/3 [00:02<00:00,  1.08it/s]

# %%
# pearsonr is used by default to compare networks. Other methods are available using the parameter association_metric.
# compare_structure runs in parallel by default. Use workers to specify the number of processes to run in parallel.
# TODO definir bien cómo es la comparación de redes

compare_structure(networks, workers=2, association_metric=spearmanr);
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]

# %%
# just like characterize_network, compare_structure function allows you to provide the list of chosen properties for analysis using the parameter selected_props

# my_properties = ['EntropyPKout', 'ClusteringCoefficient', 'OutDegree', 'Density', 'Regulators']
my_properties = ['Complex Feed-Forward Circuits', 'Feed-Forward Circuits', '3-Feedback Loops']
# ERROR
compare_structure(networks, workers=2, association_metric=spearmanr, selected_props= my_properties);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jmere\Dropbox (FreyreLab)\netective\docs\module_tutorial.ipynb Cell 22 line <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/docs/module_tutorial.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> my_properties = ['Complex Feed-Forward Circuits', 'Feed-Forward Circuits', '3-Feedback Loops']
#       <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/docs/module_tutorial.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # ERROR
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jmere/Dropbox%20%28FreyreLab%29/netective/docs/module_tutorial.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> compare_structure(networks, workers=2, association_metric=spearmanr, selected_props= my_properties);
#
# NameError: name 'compare_structure' is not defined

# %%
# Lets create a dict with 10 random networks to see the power of compare_structure

erdos_nets = {f'erdos_{i}': nx.fast_gnp_random_graph(100, 0.1, directed=True) for i in range(10)}
sf_nets = {f'SF_{i}': nx.DiGraph(nx.scale_free_graph(100)) for i in range(10)}

name_nets = {**erdos_nets, **sf_nets}

compare_structure(name_nets);
# Out:
# 100%|██████████| 20/20 [00:04<00:00,  4.57it/s]

# %%
# Netective is also capable to compare a directed network with an undirected one
# A subset of properties they share is selected for analysis
# Biological normalization not recommended for this type of comparison

# Let's create a random UNDIRECTED network.
G = nx.erdos_renyi_graph(100, 0.3, directed=False)
# Let's create a second network to compare to the first one. Notice this is a directed network
H = nx.path_graph(50, create_using=nx.DiGraph)

networks = {"my_network_G": G, "my_network_H": H}
compare_structure(networks, norm='network', workers='auto');
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]

# %% [markdown]
# <br>

# %% [markdown]
# ### **Submodule `structure`** 🕸️📐

# %%
from netective.structure.structure import Structure

# %%
# The object Structure allows you to observe a graph constantly.

G = nx.erdos_renyi_graph(100, 0.2, directed=True)
s = Structure(G)
s.get_props()
# Out:
# Properties used for analysis:
# Average Degree for Nearest Neighbors (Undirected)
# Average Local Efficiency
# Average Degree for Nearest Neighbors (Out-Out)
# Average Shortest Path Length
# Betweenness Centrality
# Center
# Clustering Coefficient
# Complex Feed-Forward Circuits
# Degree
# Density
# Diameter
# Eccentricity
# Entropy of Degree Distribution
# Entropy of Out-Degree Distribution
# Feed-Forward Circuits
# 3-Feedback Loops
# Gene % in the Giant Component
# Gini Index
# Global Efficiency
# In-Degree
# Locality Index
# Max Degree
# Max In-Dregree
# Max Out-Degree
# Number of Arcs
# Number of Edges
# Number of Nodes
# Out-Degree
# Periphery
# Radius
# Regulators
# Rich Club Coefficient
# Self-Loops
# Self Regulations
# Subgraph Centrality
# Undirected Density
# Undirected Gini Index
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:259: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   skewness = skew(data, nan_policy="omit")
# C:\Users\jmere\Dropbox (FreyreLab)\netective\src\netective\utils.py:260: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   kurt = kurtosis(data, nan_policy="omit")
# ({'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Local Efficiency': 0.6819031235445017,
#    'Average Shortest Path Length': 1.638989898989899,
#    'Center': 100,
#    'Diameter': 2,
#    'Global Efficiency': 0.6805050505050505,
#    'Periphery': 100,
#    'Radius': 2,
#    'Complex Feed-Forward Circuits': 471,
#    'Feed-Forward Circuits': 4190,
#    '3-Feedback Loops': 2602,
#    'Entropy of Degree Distribution': 4.044772064274538,
#    'Max Degree': 53,
#    'Number of Edges': 1787,
#    'Number of Nodes': 100,
#    'Self-Loops': 0,
#    'Undirected Gini Index': 0.07764969222160023,
#    'Density': 0.1975,
#    'Entropy of Out-Degree Distribution': 3.9493743376069537,
#    'Gini Index': 0.11920506329113956,
#    'Max In-Dregree': 31,
#    'Max Out-Degree': 32,
#    'Number of Arcs': 1975,
#    'Regulators': 100,
#    'Self Regulations': 0,
#    'Gene % in the Giant Component': 100,
#    'Undirected Density': 0.1787}},
#  {'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Degree for Nearest Neighbors (Undirected)': (36.48525468088871,
#     0.4118595777347305,
#     -0.38249358344914763,
#     -0.28136747619135605),
#    'Clustering Coefficient': (0.36627242160031365,
#     0.00037625736582263777,
#     -0.11119041077183127,
#     0.2609942036509798),
#    'Rich Club Coefficient': (0.4657471947552222,
#     0.034521502325674615,
#     1.886412045211713,
#     2.305862333800789),
#    'Betweenness Centrality': (31.63,
#     84.06706300780957,
#     0.6510922335087397,
#     2.6043447561195574),
#    'Eccentricity': (2.0, 0.0, nan, nan),
#    'Average Degree for Nearest Neighbors (Out-Out)': (19.790760852467084,
#     0.5395059173654007,
#     -0.13492769655851003,
#     0.6119006206384201),
#    'Degree': (35.74,
#     27.325656565656562,
#     -0.21421846846949005,
#     1.5140335513447898),
#    'Locality Index': (0.21258749917751124,
#     0.0016651210988338722,
#     0.17336799701973482,
#     1.2887278354798708),
#    'Subgraph Centrality': (72586987660831.45,
#     4.6369856711389415e+26,
#     0.6120335428815187,
#     2.241170924870233),
#    'In-Degree': (19.75,
#     16.3510101010101,
#     -0.021707156921926093,
#     0.32063087908647736),
#    'Out-Degree': (19.75,
#     17.421717171717173,
#     0.27951296567130196,
#     -0.35972362584148243)}})

# %%
# if the graphs has not changed, it returned the curret props dict
s.get_props()
# Out:
# ({'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Local Efficiency': 0.6819031235445017,
#    'Average Shortest Path Length': 1.638989898989899,
#    'Center': 100,
#    'Diameter': 2,
#    'Global Efficiency': 0.6805050505050505,
#    'Periphery': 100,
#    'Radius': 2,
#    'Complex Feed-Forward Circuits': 471,
#    'Feed-Forward Circuits': 4190,
#    '3-Feedback Loops': 2602,
#    'Entropy of Degree Distribution': 4.044772064274538,
#    'Max Degree': 53,
#    'Number of Edges': 1787,
#    'Number of Nodes': 100,
#    'Self-Loops': 0,
#    'Undirected Gini Index': 0.07764969222160023,
#    'Density': 0.1975,
#    'Entropy of Out-Degree Distribution': 3.9493743376069537,
#    'Gini Index': 0.11920506329113956,
#    'Max In-Dregree': 31,
#    'Max Out-Degree': 32,
#    'Number of Arcs': 1975,
#    'Regulators': 100,
#    'Self Regulations': 0,
#    'Gene % in the Giant Component': 100,
#    'Undirected Density': 0.1787}},
#  {'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Degree for Nearest Neighbors (Undirected)': (36.48525468088871,
#     0.4118595777347305,
#     -0.38249358344914763,
#     -0.28136747619135605),
#    'Clustering Coefficient': (0.36627242160031365,
#     0.00037625736582263777,
#     -0.11119041077183127,
#     0.2609942036509798),
#    'Rich Club Coefficient': (0.4657471947552222,
#     0.034521502325674615,
#     1.886412045211713,
#     2.305862333800789),
#    'Betweenness Centrality': (31.63,
#     84.06706300780957,
#     0.6510922335087397,
#     2.6043447561195574),
#    'Eccentricity': (2.0, 0.0, nan, nan),
#    'Average Degree for Nearest Neighbors (Out-Out)': (19.790760852467084,
#     0.5395059173654007,
#     -0.13492769655851003,
#     0.6119006206384201),
#    'Degree': (35.74,
#     27.325656565656562,
#     -0.21421846846949005,
#     1.5140335513447898),
#    'Locality Index': (0.21258749917751124,
#     0.0016651210988338722,
#     0.17336799701973482,
#     1.2887278354798708),
#    'Subgraph Centrality': (72586987660831.45,
#     4.6369856711389415e+26,
#     0.6120335428815187,
#     2.241170924870233),
#    'In-Degree': (19.75,
#     16.3510101010101,
#     -0.021707156921926093,
#     0.32063087908647736),
#    'Out-Degree': (19.75,
#     17.421717171717173,
#     0.27951296567130196,
#     -0.35972362584148243)}})

# %%
# but recalculates the props if the graph changes without creating a new instance of the class.
G.add_edge("A", "B")
s.get_props()
# Out:
# Properties used for analysis:
# Average Degree for Nearest Neighbors (Undirected)
# Average Local Efficiency
# Average Degree for Nearest Neighbors (Out-Out)
# Average Shortest Path Length
# Betweenness Centrality
# Center
# Clustering Coefficient
# Complex Feed-Forward Circuits
# Degree
# Density
# Diameter
# Eccentricity
# Entropy of Degree Distribution
# Entropy of Out-Degree Distribution
# Feed-Forward Circuits
# 3-Feedback Loops
# Gene % in the Giant Component
# Gini Index
# Global Efficiency
# In-Degree
# Locality Index
# Max Degree
# Max In-Dregree
# Max Out-Degree
# Number of Arcs
# Number of Edges
# Number of Nodes
# Out-Degree
# Periphery
# Radius
# Regulators
# Rich Club Coefficient
# Self-Loops
# Self Regulations
# Subgraph Centrality
# Undirected Density
# Undirected Gini Index
# ({'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Local Efficiency': 0.6819031235445017,
#    'Average Shortest Path Length': 1.638989898989899,
#    'Center': 100,
#    'Diameter': 2,
#    'Global Efficiency': 0.6805050505050505,
#    'Periphery': 100,
#    'Radius': 2,
#    'Complex Feed-Forward Circuits': 471,
#    'Feed-Forward Circuits': 4190,
#    '3-Feedback Loops': 2602,
#    'Entropy of Degree Distribution': 4.104695807167391,
#    'Max Degree': 53,
#    'Number of Edges': 1788,
#    'Number of Nodes': 102,
#    'Self-Loops': 0,
#    'Undirected Gini Index': 0.09513313155239744,
#    'Density': 0.1975,
#    'Entropy of Out-Degree Distribution': 4.030776467297211,
#    'Gini Index': 0.13591529729300678,
#    'Max In-Dregree': 31,
#    'Max Out-Degree': 32,
#    'Number of Arcs': 1976,
#    'Regulators': 101,
#    'Self Regulations': 0,
#    'Gene % in the Giant Component': 100,
#    'Undirected Density': 0.1787}},
#  {'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Degree for Nearest Neighbors (Undirected)': (35.7894653734203,
#     24.849506694765306,
#     -6.7554296582605575,
#     44.442385486223586),
#    'Clustering Coefficient': (0.3590906094120722,
#     0.0029732619146834176,
#     -5.636806901352378,
#     34.67485948491949),
#    'Rich Club Coefficient': (0.46546366340088635,
#     0.03458607128091943,
#     1.8840495267084958,
#     2.299045802828193),
#    'Betweenness Centrality': (31.63,
#     84.06706300780957,
#     0.6510922335087397,
#     2.6043447561195574),
#    'Eccentricity': (2.0, 0.0, nan, nan),
#    'Average Degree for Nearest Neighbors (Out-Out)': (19.402706718104984,
#     8.132670721943752,
#     -6.240445023364907,
#     39.87390294765424),
#    'Degree': (35.05882352941177,
#     50.21432731508446,
#     -2.138323550928874,
#     8.979525291604386),
#    'Locality Index': (0.2084191168406973,
#     0.002509520657865862,
#     -1.1775267497652038,
#     4.900238503323866),
#    'Subgraph Centrality': (71163713392971.97,
#     5.5680472590281394e+26,
#     0.05868547166530688,
#     2.3450740898508116),
#    'In-Degree': (19.372549019607842,
#     23.22616967579111,
#     -1.046685466011101,
#     3.3571220992552),
#    'Out-Degree': (19.372549019607842,
#     24.275674626286154,
#     -0.7912491276981318,
#     2.7320622787623075)}})

# %%
s.norm = "network"
s.get_props()
# Out:
# Properties used for analysis:
# Average Degree for Nearest Neighbors (Undirected)
# Average Local Efficiency
# Average Degree for Nearest Neighbors (Out-Out)
# Average Shortest Path Length
# Betweenness Centrality
# Center
# Clustering Coefficient
# Complex Feed-Forward Circuits
# Degree
# Density
# Diameter
# Eccentricity
# Entropy of Degree Distribution
# Entropy of Out-Degree Distribution
# Feed-Forward Circuits
# 3-Feedback Loops
# Gene % in the Giant Component
# Gini Index
# Global Efficiency
# In-Degree
# Locality Index
# Max Degree
# Max In-Dregree
# Max Out-Degree
# Number of Arcs
# Number of Edges
# Number of Nodes
# Out-Degree
# Periphery
# Radius
# Regulators
# Rich Club Coefficient
# Self-Loops
# Self Regulations
# Subgraph Centrality
# Undirected Density
# Undirected Gini Index
#
#
# Properties excluded from analysis due to lack of normalization:
# Rich Club Coefficient
# Number of Edges
# Number of Nodes
# Number of Arcs
# ({'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Local Efficiency': 0.6819031235445017,
#    'Average Shortest Path Length': 0.016555453525150494,
#    'Center': 1.0,
#    'Diameter': 0.020202020202020204,
#    'Global Efficiency': 0.6805050505050505,
#    'Periphery': 1.0,
#    'Radius': 0.020202020202020204,
#    'Complex Feed-Forward Circuits': 0.00045719277810133953,
#    'Feed-Forward Circuits': 0.004067171423024656,
#    '3-Feedback Loops': 0.0025257231605513492,
#    'Entropy of Degree Distribution': 0.6151729838545605,
#    'Max Degree': 0.5196078431372549,
#    'Self-Loops': 0.0,
#    'Undirected Gini Index': 0.09513313155239744,
#    'Density': 0.1975,
#    'Entropy of Out-Degree Distribution': 0.6040946523511407,
#    'Gini Index': 0.13591529729300678,
#    'Max In-Dregree': 0.30392156862745096,
#    'Max Out-Degree': 0.3137254901960784,
#    'Regulators': 0.9901960784313726,
#    'Self Regulations': 0.0,
#    'Gene % in the Giant Component': 1.0,
#    'Undirected Density': 0.1787}},
#  {'d7a37f11-d178-47fa-9de4-6823243da439': {'Average Degree for Nearest Neighbors (Undirected)': (0.35435114231109216,
#     0.002435987324258926,
#     -6.7554296582605655,
#     44.44238548622367),
#    'Clustering Coefficient': (0.3590906094120722,
#     0.0029732619146834176,
#     -5.636806901352378,
#     34.67485948491949),
#    'Betweenness Centrality': (0.006520305091733665,
#     3.5724266934405974e-06,
#     0.6510922335087369,
#     2.6043447561195565),
#    'Eccentricity': (0.0202020202020202, 1.2158648638808308e-35, nan, nan),
#    'Average Degree for Nearest Neighbors (Out-Out)': (0.1921060071099503,
#     0.0007972424979848791,
#     -6.240445023364905,
#     39.873902947654216),
#    'Degree': (0.3437139561707035,
#     0.0048264443786125,
#     -2.1383235509288694,
#     8.979525291604377),
#    'Locality Index': (0.2084191168406973,
#     0.002509520657865862,
#     -1.1775267497652038,
#     4.900238503323866),
#    'Subgraph Centrality': (9.933815770746434e-29,
#     1.0849704544319818e-57,
#     0.05868547166530442,
#     2.34507408985081),
#    'In-Degree': (0.18992695117262592,
#     0.0022324269200106796,
#     -1.0466854660111027,
#     3.3571220992552027),
#    'Out-Degree': (0.18992695117262598,
#     0.002333302059427735,
#     -0.7912491276981368,
#     2.732062278762311)}})

# %% [markdown]
# ### **Submodule `stats`** 🕸️📐

# %% [markdown]
# This module allows you to evaluate an inferred network against a gold standard.

# %%
# import the module
from netective.stats import stats

# %%
from netective.utils import parse_network
pred = 'assets\\short_100226_v2019_sFL_dAllInc_BSs.pred'
gs = 'assets\\short_GS.txt'


pred_graph = parse_network(pred, delimiter='\t', directed=True, score=True, use_position_as_score=False)

gold_standard_graph = parse_network(gs, delimiter='\t', directed=True)

bin_stats = stats.NetworkInferenceStats(gold_standard_graph, pred_graph, greater_score_is_better=False, allow_self_loops=True, cutoff=False)
# cutoff is set to False to avoid trimming the prediction file

# %%
# get the area under the ROC curve
bin_stats.area_under_roc_curve()
# Out:
# 0.5144585100062539

# %%
# get the area under the precision-recall curve
bin_stats.area_under_precision_recall_curve()
# Out:
# 0.14662813743217454

# %%
# plot the precision recall curve
bin_stats.plot_precision_recall_curve()

# %%
# plot the ROC curve
bin_stats.plot_roc_curve()

# %% [markdown]
# The computations and plots generated above, use the cutoff provided at the instatiation of the NetworkInferenceStats class.
#
# If you want to change the cutoff value, you can do so by changing the cutoff attribute of the class and then calling the plot functions again.

# %%
bin_stats.cutoff = 400
bin_stats.plot_precision_recall_curve()

# %% [markdown]
# You can also indicate the cutoff value when calling the method for a specific application:

# %%
bin_stats.plot_precision_recall_curve(cutoff=100)

# %% [markdown]
# This won't change the associated cutoff value

# %%
bin_stats.plot_precision_recall_curve()
