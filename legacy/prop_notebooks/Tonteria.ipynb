# %%
from freyrelab.regnets.regnet import RegNet

from netective import pipeline as pip

# %%
G = RegNet()
n_nodes = 40
G.add_nodes_from(range(n_nodes))
G.add_edges_from([(i,j) for i in range(n_nodes//2) for j in range(n_nodes)])

# %%
pip.characterization(G, net_name='dummy', selected_props=['GiniIndex', 'LocalitIndex'])
# Out:
# Properties used for analysis:  GiniIndex
#
# <class 'freyrelab.regnets.regnet.RegNet'>
# G:\Mi unidad\Respaldo\Genomicas\netective\src\netective\pipeline.py:299: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig_scalar.show()
