# %%
def get_bit(net, id):
    print(net == id)

get_bit(net=0b1100, id=0b1101)
# Out:
# False

# %%
import numpy as np
foo = [True, False, False, False]
mask = bin(np.packbits(foo).item() >> 4)
spam = 0b1000

print(mask, bin(spam))
mask == bin(spam)
# Out:
# 0b1000 0b1000
# True
