# %% [markdown]
# # Structural robustness of mammalian transcription factor networks reveals plasticity across development
#
# ## Human Analysis

# %% [markdown]
# #### External imports

# %%
import os
import pandas as pd
import networkx as nx
import numpy as np
import re

# %% [markdown]
# #### Auxiliar Fxns

# %%
def get_human_names(root, code_names):
    name = re.split('buffer.5000', root)
    name = name[1]
    name = name.replace('\\','')
    return code_names[name]

# %%
def extract_networks(directory_name=str, files_ignore=list, cols=tuple, feo=True, code_names=dict):
    networks = {}
    for root, dir, files in os.walk(directory_name):
        if len(files) != 0 and files[0] not in files_ignore:
          path = os.path.join(os.getcwd(), root, files[0])
          net = nx.DiGraph()
          name = get_human_names(root, code_names)
          if feo:
               f = np.genfromtxt(path, dtype= str, delimiter='\t', usecols= cols)
               net.add_edges_from(f)
          else:
               net = nx.read_edgelist(path, create_using= nx.DiGraph)
          
          networks[name] = net
    return networks

# %% [markdown]
# #### Biological Networks

# %%
hg19CellTypeValues = { "AG10803-DS12374" : "skin fibroblast (abdomen)",
"AoAF-DS13513" : "aortic adventitial fibroblast",
"CD20-DS18208" : "B-cells (CD20+)",
"CD34-DS12274" : "Hematopoietic stem/progenitor cells (CD34+)",
"fBrain-DS11872" : "fetal brain",
"fHeart-DS12531" : "fetal heart",
"fLung-DS14724" : "fetal lung",
"GM06990-DS7748" : "B-lymphoblastoid cells (individual 06990)",
"GM12865-DS12436" : "B-lymphoblastoid cells (individual 12865)",
"HAEpiC-DS12663" : "amniotic epithelium",
"HAh-DS15192" : "hippocampal astrocyte",
"HCF-DS12501" : "cardiac fibroblast",
"HCM-DS12599" : "cardiac myocyte",
"HCPEpiC-DS12447" : "choroid plexus epithelium",
"HEEpiC-DS12763" : "esophageal epithelium",
"HepG2-DS7764" : "hepatic (hepatoblastoma)",
"hESCT0-DS11909": "embryonic stem cells (line H7)",
"HFF-DS15115" : "foreskin fibroblast",
"HIPEpiC-DS12684" : "iris pigment epithelium",
"HMF-DS13368" : "mammary fibroblast",
"HMVEC_dBlAd-DS13337" : "microvascular endothelium, adult, blood",
"HMVEC_dBlNeo-DS13242" : "microvascular endothelium, neonatal, blood",
"HMVEC_dLyNeo-DS13150" : "microvascular endothelium, neonatal, lympathic",
"HMVEC_LLy-DS13185" : "microvascular endothelium, lung-derived",
"HPAF-DS13411" : "pulmonary artery fibroblast",
"HPdLF-DS13573" : "periodontal ligament fibroblast",
"HPF-DS13390" : "pulmonary fibroblast",
"HRCE-DS10666" : "renal cortical epithelium",
"HSMM-DS14426" : "skeletal muscle myoblast",
"hTH1-DS7840" : "Th1 T-cells",
"HVMF-DS13981" : "villous mesenchymal fibroblast",
"IMR90-DS13219" : "pulmonary fibroblast, fetal",
"K562-DS9767" : "erythroid (erythroleukemia)",
"NB4-DS12543" : "granulocytic (promyelocytic leukemia)",
"NHA-DS12800" : "astrocyte",
"NHDF_Ad-DS12863" : "dermal fibroblast, adult",
"NHDF_Neo-DS11923" : "dermal fibroblast, neonatal",
"NHLF-DS12829" : "lung fibroblast",
"SAEC-DS10518" : "small airway epithelium",
"SkMC-DS11949" : "skeletal myocytes",
"SKNSH-DS8482" : "neuroblastoid (neuroblastoma)"
}

human_networks = extract_networks('h:\\Mi unidad\\Respaldo\\Genomicas\\netective\\data\\human_net', [], (0,1), feo=False, code_names=hg19CellTypeValues)
human_networks
# Out:
# {'aortic adventitial fibroblast': <networkx.classes.digraph.DiGraph at 0x27fcada4970>,
#  'B-cells (CD20+)': <networkx.classes.digraph.DiGraph at 0x27fcada4b20>,
#  'Hematopoietic stem/progenitor cells (CD34+)': <networkx.classes.digraph.DiGraph at 0x27fcada4b50>,
#  'fetal brain': <networkx.classes.digraph.DiGraph at 0x27fcada4a30>,
#  'fetal heart': <networkx.classes.digraph.DiGraph at 0x27fc85418b0>,
#  'fetal lung': <networkx.classes.digraph.DiGraph at 0x27fc84d6550>,
#  'B-lymphoblastoid cells (individual 06990)': <networkx.classes.digraph.DiGraph at 0x27fcada4940>,
#  'B-lymphoblastoid cells (individual 12865)': <networkx.classes.digraph.DiGraph at 0x27fdd72c070>,
#  'amniotic epithelium': <networkx.classes.digraph.DiGraph at 0x27fdd72c100>,
#  'hippocampal astrocyte': <networkx.classes.digraph.DiGraph at 0x27fdd72c040>,
#  'cardiac fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c0a0>,
#  'cardiac myocyte': <networkx.classes.digraph.DiGraph at 0x27fdd72c160>,
#  'choroid plexus epithelium': <networkx.classes.digraph.DiGraph at 0x27fdd72c190>,
#  'esophageal epithelium': <networkx.classes.digraph.DiGraph at 0x27fdd72c130>,
#  'hepatic (hepatoblastoma)': <networkx.classes.digraph.DiGraph at 0x27fdd72c0d0>,
#  'embryonic stem cells (line H7)': <networkx.classes.digraph.DiGraph at 0x27fdd72c1f0>,
#  'foreskin fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c280>,
#  'iris pigment epithelium': <networkx.classes.digraph.DiGraph at 0x27fdd72c220>,
#  'mammary fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c1c0>,
#  'microvascular endothelium, adult, blood': <networkx.classes.digraph.DiGraph at 0x27fdd72c2e0>,
#  'microvascular endothelium, neonatal, blood': <networkx.classes.digraph.DiGraph at 0x27fdd72c340>,
#  'microvascular endothelium, neonatal, lympathic': <networkx.classes.digraph.DiGraph at 0x27fdd72c370>,
#  'microvascular endothelium, lung-derived': <networkx.classes.digraph.DiGraph at 0x27fdd72c310>,
#  'pulmonary artery fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c2b0>,
#  'periodontal ligament fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c3a0>,
#  'pulmonary fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c400>,
#  'renal cortical epithelium': <networkx.classes.digraph.DiGraph at 0x27fdd72c3d0>,
#  'skeletal muscle myoblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c250>,
#  'Th1 T-cells': <networkx.classes.digraph.DiGraph at 0x27fdd72c4c0>,
#  'villous mesenchymal fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c460>,
#  'pulmonary fibroblast, fetal': <networkx.classes.digraph.DiGraph at 0x27fdd72c520>,
#  'erythroid (erythroleukemia)': <networkx.classes.digraph.DiGraph at 0x27fdd72c430>,
#  'granulocytic (promyelocytic leukemia)': <networkx.classes.digraph.DiGraph at 0x27fdd72c580>,
#  'astrocyte': <networkx.classes.digraph.DiGraph at 0x27fdd72c4f0>,
#  'dermal fibroblast, adult': <networkx.classes.digraph.DiGraph at 0x27fdd72c550>,
#  'dermal fibroblast, neonatal': <networkx.classes.digraph.DiGraph at 0x27fdd72c490>,
#  'lung fibroblast': <networkx.classes.digraph.DiGraph at 0x27fdd72c5b0>,
#  'small airway epithelium': <networkx.classes.digraph.DiGraph at 0x27fcadc1460>,
#  'skeletal myocytes': <networkx.classes.digraph.DiGraph at 0x27fcadc1400>,
#  'neuroblastoid (neuroblastoma)': <networkx.classes.digraph.DiGraph at 0x27fcadc1490>,
#  'skin fibroblast (abdomen)': <networkx.classes.digraph.DiGraph at 0x27fc84d15b0>}

# %%
25*5
# Out:
# 125

# %%
for net_id, net in human_networks.items():
    name = net_id.replace(' ','_').replace(',','').replace('+','').replace('/','_') + '.txt'
    print(net_id, name)
    dir = './../../data/corrected_human_nets/'
    new_file = os.path.join(dir,name)
    with open(new_file, "w") as f:
        nx.write_edgelist(G= net, delimiter='\t', path= new_file, data= False)
# Out:
# aortic adventitial fibroblast aortic_adventitial_fibroblast.txt
# B-cells (CD20+) B-cells_(CD20).txt
# Hematopoietic stem/progenitor cells (CD34+) Hematopoietic_stem_progenitor_cells_(CD34).txt
# fetal brain fetal_brain.txt
# fetal heart fetal_heart.txt
# fetal lung fetal_lung.txt
# B-lymphoblastoid cells (individual 06990) B-lymphoblastoid_cells_(individual_06990).txt
# B-lymphoblastoid cells (individual 12865) B-lymphoblastoid_cells_(individual_12865).txt
# amniotic epithelium amniotic_epithelium.txt
# hippocampal astrocyte hippocampal_astrocyte.txt
# cardiac fibroblast cardiac_fibroblast.txt
# cardiac myocyte cardiac_myocyte.txt
# choroid plexus epithelium choroid_plexus_epithelium.txt
# esophageal epithelium esophageal_epithelium.txt
# hepatic (hepatoblastoma) hepatic_(hepatoblastoma).txt
# embryonic stem cells (line H7) embryonic_stem_cells_(line_H7).txt
# foreskin fibroblast foreskin_fibroblast.txt
# iris pigment epithelium iris_pigment_epithelium.txt
# mammary fibroblast mammary_fibroblast.txt
# microvascular endothelium, adult, blood microvascular_endothelium_adult_blood.txt
# microvascular endothelium, neonatal, blood microvascular_endothelium_neonatal_blood.txt
# microvascular endothelium, neonatal, lympathic microvascular_endothelium_neonatal_lympathic.txt
# microvascular endothelium, lung-derived microvascular_endothelium_lung-derived.txt
# pulmonary artery fibroblast pulmonary_artery_fibroblast.txt
# periodontal ligament fibroblast periodontal_ligament_fibroblast.txt
# pulmonary fibroblast pulmonary_fibroblast.txt
# renal cortical epithelium renal_cortical_epithelium.txt
# skeletal muscle myoblast skeletal_muscle_myoblast.txt
# Th1 T-cells Th1_T-cells.txt
# villous mesenchymal fibroblast villous_mesenchymal_fibroblast.txt
# pulmonary fibroblast, fetal pulmonary_fibroblast_fetal.txt
# erythroid (erythroleukemia) erythroid_(erythroleukemia).txt
# granulocytic (promyelocytic leukemia) granulocytic_(promyelocytic_leukemia).txt
# astrocyte astrocyte.txt
# dermal fibroblast, adult dermal_fibroblast_adult.txt
# dermal fibroblast, neonatal dermal_fibroblast_neonatal.txt
# lung fibroblast lung_fibroblast.txt
# small airway epithelium small_airway_epithelium.txt
# skeletal myocytes skeletal_myocytes.txt
# neuroblastoid (neuroblastoma) neuroblastoid_(neuroblastoma).txt
# skin fibroblast (abdomen) skin_fibroblast_(abdomen).txt

# %%
test = {
    i : j 
    for k, (i,j) in enumerate(human_networks.items())
    if k < 5 or i == 'erythroid (erythroleukemia)'
}
test
# Out:
# {'aortic adventitial fibroblast': <networkx.classes.digraph.DiGraph at 0x1bf54823940>,
#  'B-cells (CD20+)': <networkx.classes.digraph.DiGraph at 0x1bf548236a0>,
#  'Hematopoietic stem/progenitor cells (CD34+)': <networkx.classes.digraph.DiGraph at 0x1bf547fa580>,
#  'fetal brain': <networkx.classes.digraph.DiGraph at 0x1bf547eaf40>,
#  'fetal heart': <networkx.classes.digraph.DiGraph at 0x1bf541eddc0>,
#  'erythroid (erythroleukemia)': <networkx.classes.digraph.DiGraph at 0x1bf548239a0>}

# %% [markdown]
# #### Synthetic networks
#
# ER and BA analogous ensembles to each biological network.

# %%
from freyrelab.nets import models

seed = 42
synth_graphs = {}

for net_id, G in human_networks.items():
    n = G.number_of_nodes()
    m = G.number_of_edges()
    for i in range(1,2):
        synth_graphs[f'BA_{net_id}_{i}'] = nx.DiGraph(models.barabasi_albert_graph(n))
        synth_graphs[f'ER_{net_id}_{i}'] = nx.erdos_renyi_graph(n, m/(n*(n-1)), seed=seed, directed=True)

networks = {**human_networks, **synth_graphs}

# %% [markdown]
# #### Graphs overall info

# %%
nets_info = {'Cell Type': [],
        'Nodes': [],
        'Edges': [],
        'Density': []
        }

for name,G in test.items():
    n_nodes = G.number_of_nodes()
    n_edges = G.number_of_edges()
    density = n_edges / (n_nodes * (n_nodes - 1))
    nets_info['Cell Type'].append(name)
    nets_info['Nodes'].append(n_nodes)
    nets_info['Edges'].append(n_edges)
    nets_info['Density'].append(density)

info_df = pd.DataFrame.from_dict(nets_info)
info_df
# Out:
#                                      Cell Type  Nodes  Edges   Density
# 0                aortic adventitial fibroblast    529  14795  0.052969
# 1                              B-cells (CD20+)    515  16723  0.063175
# 2  Hematopoietic stem/progenitor cells (CD34+)    526  16461  0.059609
# 3                                  fetal brain    519  11698  0.043513
# 4                                  fetal heart    516  14295  0.053793
# 5                  erythroid (erythroleukemia)    493   9099  0.037513

# %% [markdown]
# ### Netective Analysis

# %%
from netective import compare_structure

# %% [markdown]
# `!!!!AGUAS!!!!`

# %%
compare_structure(test, norm='biological', workers='auto')
# Out:
# Properties used for analysis:
# Average Degree for Nearest Neighbors (Undirected)
# Average Local Efficiency
# Average Degree for Nearest Neighbors (Out-Out)
# Average Shortest Path Length
# Betweenness Centrality
# Center
# Clustering Coefficient
# Complex Feed-Forward Circuits
# Degree
# Density
# Diameter
# Eccentricity
# Entropy of Degree Distribution
# Entropy of Out-Degree Distribution
# 3-Feedback Loops
# Gene % in the Giant Component
# Gini Index
# Global Efficiency
# In-Degree
# Locality Index
# Max Degree
# Max In-Dregree
# Max Out-Degree
# Number of Arcs
# Number of Edges
# Number of Nodes
# Out-Degree
# Periphery
# Radius
# Regulators
# Rich Club Coefficient
# Self-Loops
# Self Regulations
# Subgraph Centrality
# Undirected Density
# Undirected Gini Index
#   0%|          | 0/7 [00:00<?, ?it/s]
# Running aortic adventitial fibroblast
# Running B-cells (CD20+)
# Running Hematopoietic stem/progenitor cells (CD34+)
# Running fetal brain
# Running fetal heart
# Running erythroid (erythroleukemia)
#  86%|████████▌ | 6/7 [00:46<00:07,  7.77s/it]
